# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_parquet("X_train_observed.parquet")
df.describe()
# Out:
#        absolute_humidity_2m:gm3  air_density_2m:kgm3  ceiling_height_agl:m  \
# count             118669.000000        118669.000000          96422.000000
# mean                   6.652576             1.249064           2907.949219
# std                    2.796409             0.036317           2570.401855
# min                    0.700000             1.145000             27.799999
# 25%                    4.400000             1.224000           1102.900024
# 50%                    6.300000             1.247000           1882.400024
# 75%                    8.600000             1.272000           3969.750000
# max                   17.500000             1.427000          12328.500000
#
#        clear_sky_energy_1h:J  clear_sky_rad:W  cloud_base_agl:m  \
# count           1.186690e+05    118669.000000     110603.000000
# mean            5.994018e+05       166.500381       1737.142212
# std             8.797980e+05       244.907578       1815.570557
# ...

# %% [markdown]
# ### Head for X_train_observed

# %%
df.head()
# Out:
#         date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 0 2019-06-02 22:00:00                       7.7                1.230
# 1 2019-06-02 22:15:00                       7.7                1.229
# 2 2019-06-02 22:30:00                       7.7                1.228
# 3 2019-06-02 22:45:00                       7.7                1.226
# 4 2019-06-02 23:00:00                       7.7                1.225
#
#    ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 0           1744.900024                    0.0              0.0
# 1           1734.000000                    0.0              0.0
# 2           1723.500000                    0.0              0.0
# 3           1713.400024                    0.0              0.0
# 4           1703.599976                    0.0              0.0
#
#    cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  ...  \
# 0       1744.900024              0.0      280.299988            0.0  ...
# ...

# %% [markdown]
# ### Tail for X_train_observed

# %%
df.tail()
# Out:
#              date_forecast  absolute_humidity_2m:gm3  air_density_2m:kgm3  \
# 118664 2022-10-21 00:00:00                       5.0                1.292
# 118665 2022-10-21 00:15:00                       5.0                1.292
# 118666 2022-10-21 00:30:00                       5.0                1.292
# 118667 2022-10-21 00:45:00                       5.0                1.292
# 118668 2022-10-21 01:00:00                       5.0                1.292
#
#         ceiling_height_agl:m  clear_sky_energy_1h:J  clear_sky_rad:W  \
# 118664                   NaN                    0.0              0.0
# 118665                   NaN                    0.0              0.0
# 118666                   NaN                    0.0              0.0
# 118667                   NaN                    0.0              0.0
# 118668                   NaN                    0.0              0.0
#
#         cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  diffuse_rad:W  ...  \
# ...

# %% [markdown]
# ### Head for target

# %%
df_target=pd.read_parquet("train_targets.parquet")
#df_target.describe()
df_target.head()
# Out:
#                  time  pv_measurement
# 0 2019-06-02 22:00:00            0.00
# 1 2019-06-02 23:00:00            0.00
# 2 2019-06-03 00:00:00            0.00
# 3 2019-06-03 01:00:00            0.00
# 4 2019-06-03 02:00:00           19.36

# %% [markdown]
# ### Tail for target

# %%
#df_target.tail()
df_target.describe()
# Out:
#        pv_measurement
# count    34085.000000
# mean       630.594707
# std       1165.902422
# min          0.000000
# 25%          0.000000
# 50%          5.940000
# 75%        678.040000
# max       5733.420000

# %%
df_estimated=pd.read_parquet("X_train_estimated.parquet")
df_estimated.head()
# Out:
#             date_calc       date_forecast  absolute_humidity_2m:gm3  \
# 0 2022-10-27 07:00:18 2022-10-28 22:00:00                       8.4
# 1 2022-10-27 07:00:18 2022-10-28 22:15:00                       8.4
# 2 2022-10-27 07:00:18 2022-10-28 22:30:00                       8.3
# 3 2022-10-27 07:00:18 2022-10-28 22:45:00                       8.3
# 4 2022-10-27 07:00:18 2022-10-28 23:00:00                       8.2
#
#    air_density_2m:kgm3  ceiling_height_agl:m  clear_sky_energy_1h:J  \
# 0                1.233           1425.099976                    0.0
# 1                1.233           2085.899902                    0.0
# 2                1.233           2746.600098                    0.0
# 3                1.233           3407.399902                    0.0
# 4                1.233           4068.199951                    0.0
#
#    clear_sky_rad:W  cloud_base_agl:m  dew_or_rime:idx  dew_point_2m:K  ...  \
# ...

# %%
# Extract date from the 'time' column
df['date'] = pd.to_datetime(df['date_forecast']).dt.date
df_target['date'] = pd.to_datetime(df_target['time']).dt.date

# Find common dates
common_dates = pd.Series(list(set(df['date']) & set(df_target['date'])))

# Filter both DataFrames to only include rows with the common dates
filtered_df = df[df['date'].isin(common_dates)].drop('date', axis=1)
filtered_df_target = df_target[df_target['date'].isin(common_dates)].drop('date', axis=1)

# %%
filtered_df.shape
# Out:
# (118669, 46)

# %%
filtered_df_target.shape
# Out:
# (29667, 2)

# %%
filtered_df['temp_index'] = filtered_df.index // 4
averaged_df = filtered_df.groupby('temp_index').mean().reset_index(drop=True)
averaged_df.drop(columns='temp_index', inplace=True, errors='ignore')
# Out:
# /var/folders/3_/t1x42dv15n3g_668v8xtx12m0000gn/T/ipykernel_68105/1802523301.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   averaged_df = filtered_df.groupby('temp_index').mean().reset_index(drop=True)

# %%
averaged_df = averaged_df.iloc[:-1]
averaged_df.shape
# Out:
# (29667, 45)

# %%
X_train, X_test, y_train, y_test = train_test_split(averaged_df, filtered_df_target, test_size=0.2, random_state=42)

X_train = X_train.dropna()
y_train = y_train.loc[X_train.index]

X_test = X_test.dropna()
y_test = y_test.loc[X_test.index]

X_train = X_train.select_dtypes(include=[np.number])
X_test = X_test.select_dtypes(include=[np.number])
y_train = y_train.select_dtypes(include=[np.number])
y_test = y_test.select_dtypes(include=[np.number])



X_train.shape
# Out:
# (400, 45)

# %%
# Initialize the model
base_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
base_model.fit(X_train, y_train)

# Predict the target for the test data
predictions = base_model.predict(X_test)

# Calculate the Mean Squared Error between the true and predicted targets
mse = mean_squared_error(y_test, predictions)

print(f"Mean Squared Error: {mse}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/henningdropping/Documents/GitHub/Forest-Gump/A/testing.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell:/Users/henningdropping/Documents/GitHub/Forest-Gump/A/testing.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Initialize the model
# ----> <a href='vscode-notebook-cell:/Users/henningdropping/Documents/GitHub/Forest-Gump/A/testing.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> base_model = RandomForestRegressor(n_estimators=100, random_state=42)
#       <a href='vscode-notebook-cell:/Users/henningdropping/Documents/GitHub/Forest-Gump/A/testing.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> # Fit the model to the training data
#       <a href='vscode-notebook-cell:/Users/henningdropping/Documents/GitHub/Forest-Gump/A/testing.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> base_model.fit(X_train, y_train)
#
# ...

# %%
meta_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
stacking_model = StackingClassifier(
    estimators=[('random_forest', base_model)],
    final_estimator=meta_model,
    passthrough=True
)
stacking_model.fit(X_train, y_train)
y_pred = stacking_model.predict(X_test)
print("Stacking Model Accuracy: ", accuracy_score(y_test, y_pred))
